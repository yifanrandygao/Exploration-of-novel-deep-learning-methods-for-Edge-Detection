# %% [markdown]
# # MSCA 31009 Final Project
# ### Author:  Rajat Nagar, Yifan Gao
# ### Date:  August 26, 2021

# %% [markdown]
# ## 1. Prep work

# %% [markdown]
# ### 1a. Import necessary libraries

# %%
import warnings
warnings.filterwarnings("ignore")
import os, sys
from os.path import join, split, isdir, isfile, splitext, split, abspath, dirname
from PIL import Image
import numpy as np
import pandas as pd
import cv2
import shutil
import time
import datetime
import torch
from torch.utils import data
import torch.nn as nn
import torch.autograd.variable as Variable
import scipy.io as sio
from torch.nn.modules.conv import _ConvNd
from torch.nn.modules.conv import _single, _pair, _triple
from torch.optim.optimizer import Optimizer, required
from torch.optim import lr_scheduler
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import make_grid
from torch.utils.data import DataLoader, sampler, random_split
from torch.utils.data.sampler import SubsetRandomSampler
from torchsummary import summary
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
import random

# %% [markdown]
# ### 1b. Download data & Set up folders & parameters

# %% [markdown]
# Download dataset containing test images, train images, train labels (sketch/edge of train image) and lst files (path of train and test images) from this link: https://mftp.mmcheng.net/liuyun/rcf/data/HED-BSDS.tar.gz , and extract the dataset to ROOT_DIR/data/ folder
#
# Download dataset containg test labels from this link: http://www.eecs.berkeley.edu/Research/Projects/CS/vision/grouping/BSR/BSR_bsds500.tgz Unzip the package and extract .mat files from BSR_bsds500.tgz\BSR\BSDS500\data\groundTruth\test\ to gt/ folder
#
# If you run this notebook in Linux environment, run command wget http://mftp.mmcheng.net/liuyun/rcf/data/HED-BSDS.tar.gz
#
# Download supporting package for OIS/ODS calculation from this link: https://github.com/Walstruzz/edge_eval_python/archive/refs/heads/main.zip Unzip the package, extract cxx folder to ROOT_DIR, and extract bwmorph_thin.py, correspond_pixels.py, edges_eval_dir.py from impl folder to ROOT_DIR.\
# Open edges_eval_dir.py and modify import script "from .bwmorph_thin import bwmorph_thin from .correspond_pixels import correspond_pixels" to "from bwmorph_thin import bwmorph_thin from correspond_pixels import correspond_pixels".\
# Note the files in cxx folder are only executable in Linux/Unix environment. They do not work in Windows. If do not have access to Linux/Unix, comment out the chunk code below under "Measure model performance". To compile cxx library, run command below when you use this notebook first time:
#
# cd cxx/src\
# source build.sh
#
# Download the vgg16 pretrained backbone model from this link: https://drive.google.com/file/d/1lUhPKKj-BSOH7yQL0mOIavvrUbjydPp5/view?usp=sharing, and extract the model to ROOT_DIR folder
#
# Create a tmp/RCF folder under ROOT_DIR (if you do not create the code below will automatically create)
#
# Below is the project structure. The list files contains the path for test image, and train image and label. The gt folder contains the ground true labels for test images. The train folder has 6 folders. aug_data folders contain images we are trying to sketch/apply edge detection. aug_gt folders contain train labels, which in this project are the sketches of train images drawn by humans.

# %% [raw]
# ROOT_DIR/
# |- data/
#    |- HED-BSDS/
#       |- test.lst
#       |- train_pair.lst
#       |- gt/
#          |- .mat
#       |- test/
#          |- .jpg
#       |- train/
#          |- aug_data/
#             |- .../
#                |- .jpg/
#          |- aug_data_scale_0.5/
#             |- .../
#                |- .jpg/
#          |- aug_data_scale_1.5/
#             |- .../
#                |- .jpg/
#          |- aug_gt/
#             |- .../
#                |- .png/
#          |- aug_gt_scale_0.5/
#             |- .../
#                |- .png/
#          |- aug_gt_scale_1.5/
#             |- .../
#                |- .png/
# |- tmp/
#    |- eRCF/
# |- cxx/
#    |- lib/
#    |- src/
#     - README.md
# |- vgg16convs.mat
# |- correspond_pixels.py
# |- bwmorph_thin.py
# |- edges_eval_dir.py

# %%
# Define folder/path/file variables
# Root_dir = '/home/ygao26/Desktop/final'
Root_dir = 'C:/Users/mars_/Documents/Personal Document/MSCA classes/MSCA 31009 1 Machine Learning Predictive Analytics/Final/'
tmp_folder = 'tmpERCF/eRCF' # tmp folder
data_folder = 'data/HED-BSDS' # root folder of dataset
test_lst = 'data/HED-BSDS/test.lst'
test_lst = join(Root_dir, test_lst) # test lst file
test_gt = join(Root_dir, 'data/HED-BSDS/gt/') # gt folder for test images
tmp_dir = join(Root_dir, tmp_folder) # tmp directory
test_pre = join(tmp_dir, 'epoch-10-testing-record-black') # predicted test sketches; modify accordingly
if not isdir(tmp_dir):
    os.makedirs(tmp_dir)

# %%
# Default parameters
dft_eta = 127.5 # eta threshold to determine whether edge will be annotated
dft_lambda = 0.9 # lambda to balance the number of positive and negative samples
dft_bs = 1 # batch size
dft_lr = 1.5e-6 # initial learning_rate
dft_mmtum = 0.9 # momentum
dft_wd = 2e-4 # default weight decay
dft_ss = 3 # learning rate step size
dft_gm = 0.1 # learning rate decay parameter: Gamma
dft_maxep = 11 # end epoch number (# of epochs = end epoch number - start epoch number)
dft_is = 30 # iter size
dft_step = 1 # start epoch number (useful on restarts)
dft_freq = 1000 # print frequency
dft_gpu = '0' # GPU ID
dft_tmp = tmp_folder # 'tmp folder'
dft_datap = data_folder # root folder of dataset
# dft_datap = 'C:/Users/mars_/Documents/Personal Document/MSCA classes/MSCA 31009 1 Machine Learning Predictive Analytics/Final/data/HED-BSDS/'

# enable environment for GPU use
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = dft_gpu

# %% [markdown]
# ## 2. Define BSDS Data Loader tool

# %%
# Convert image to PIL format
def prepare_image_PIL(im):
    im = im[:,:,::-1] - np.zeros_like(im) # rgb to bgr
    im -= np.array((104.00698793,116.66876762,122.67891434))
    im = np.transpose(im, (2, 0, 1)) # (H x W x C) to (C x H x W)
    return im

# Convert image to CV2 format
def prepare_image_cv2(im):
    im -= np.array((104.00698793,116.66876762,122.67891434))
    im = np.transpose(im, (2, 0, 1)) # (H x W x C) to (C x H x W)
    return im


class BSDS_Dataloader(data.Dataset):
    """
    Dataloader BSDS500
    """
    def __init__(self, root=data_folder, split='train', transform=False):
        self.root = root
        self.split = split
        self.transform = transform
        if self.split == 'train':
            self.filelist = join(self.root, 'train_pair.lst')
        elif self.split == 'test':
            self.filelist = join(self.root, 'test.lst')
        else:
            raise ValueError("Invalid split type!")
        # loop thru whole list of images and labels
        with open(self.filelist, 'r') as f:
            self.filelist = f.readlines()

    def __len__(self):
        return len(self.filelist)
    
    def __getitem__(self, index):
        if self.split == "train":
            # Split train images and labels
            img_file, lb_file = self.filelist[index].split()
            # Convert label sketch to tensor
            lb = np.array(Image.open(join(self.root, lb_file)), dtype=np.float32)
            # Need to squeeze label tensor to 2d from 3d
            if lb.ndim == 3:
                lb = np.squeeze(lb[:, :, 0])
            assert lb.ndim == 2
            # Add new dimension for label tensor
            lb = lb[np.newaxis, :, :]
            # Mask label values in a way to fit the implementation of proposed loss function
            # 0 means no annotator labeled at this pixel
            # 1 means all annotators have labeled at this pixel
            # 2 means ambiguous and we need to drop
            lb[lb == 0] = 0
            lb[np.logical_and(lb>0, lb<dft_eta)] = 2
            lb[lb >= dft_eta] = 1
        else:
            # get test image path
            img_file = self.filelist[index].rstrip()

        if self.split == "train":
            # Convert image to CV2 format if it's train
            img = np.array(cv2.imread(join(self.root, img_file)), dtype=np.float32)
            img = prepare_image_cv2(img)
            return img, lb
        else:
            # Convert image to PIL format if it's test
            img = np.array(Image.open(join(self.root, img_file)), dtype=np.float32)
            img = prepare_image_PIL(img)
            return img

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# Exploratory data analysis is difficult to conduct over computer vision problem given the nature of the dataset. Nonetheless, we try our best to give you a sense of what the dataset looks like.

# %% [markdown]
# ### 3a. Get the size of dataset

# %%
train_dataset = BSDS_Dataloader(root=dft_datap, split= "train")
test_dataset = BSDS_Dataloader(root=dft_datap,  split= "test")

# %%
print('The size of test images is %d' % len(test_dataset))
print('The size of train images and labels is %d, respectively' % len(train_dataset))
# Out:
# The size of test images is 200
# The size of train images and labels is 28800, respectively

# %% [markdown]
# ### 3b. Show test images

# %%
test_images_short = os.listdir(join(Root_dir, 'data/HED-BSDS/test/'))
test_images = list(map(lambda x: join(Root_dir, 'data/HED-BSDS/test/') + x, test_images_short))
fig = plt.figure(figsize=(12, 12))

for idx, img in enumerate(random.sample(test_images,4)):
    img = cv2.imread(img, 3)
    b,g,r = cv2.split(img)    
    img = cv2.merge([r,g,b])
    fig.add_subplot(2, 2, idx + 1)
    plt.imshow(img)
plt.show()

# %% [markdown]
# ### 3c. Show train images and labels (ground truths)

# %% [markdown]
# The train folder have 300 base images. From there, several augmentation techniques are applied to amplify the dataset, such as cropping, shear, flipping, rotatation, resizing, etc. Ultimately, 96 subfolders are created with different variation of base images. Same structure applied to the labels.

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

train_images_short = os.listdir(join(Root_dir, 'data/HED-BSDS/train/aug_data/0.0_1_0/'))
train_images = list(map(lambda x: join(Root_dir, 'data/HED-BSDS/train/aug_data/0.0_1_0/') + x, train_images_short))
train_labels_short = os.listdir(join(Root_dir, 'data/HED-BSDS/train/aug_gt/0.0_1_0/'))
train_labels = list(map(lambda x: join(Root_dir, 'data/HED-BSDS/train/aug_gt/0.0_1_0/') + x, train_labels_short))
fig = plt.figure(figsize=(16, 16))

for idx, img in enumerate(zip(train_images[5:9], train_labels[5:9])):
    img1 = cv2.imread(img[0], 3)
    b,g,r = cv2.split(img1)    
    img1 = cv2.merge([r,g,b])
    img2 = cv2.imread(img[1], 3)
    b,g,r = cv2.split(img2)    
    img2 = cv2.merge([r,g,b])
    fig.add_subplot(4, 2, idx * 2 + 1)
    plt.imshow(img1)
    fig.add_subplot(4, 2, idx * 2 + 2)
    plt.imshow(img2)
plt.show()

# %% [markdown]
# ## 4. Define utility functions

# %%
# This function uses bilinear interpolation to resize
# image to a higher resolution one
def make_bilinear_weights(size, num_channels):
    ''' Make a 2D bilinear kernel suitable for upsampling
    Stack the bilinear kernel for application to tensor,
    using Bilinear Interpolation'''
    factor = (size + 1) // 2
    if size % 2 == 1:
        center = factor - 1
    else:
        center = factor - 0.5
    og = np.ogrid[:size, :size]
    ## Interpolation calculation
    filt = (1 - abs(og[0] - center) / factor) * \
             (1 - abs(og[1] - center) / factor)
    filt = torch.from_numpy(filt)
    w = torch.zeros(num_channels, num_channels, size, size)
    for i in range(num_channels):
        w[i, i] = filt
    return w


def crop(variable, th, tw):
    ''' Crop the image to the desire dimension'''
    h, w = variable.shape[2], variable.shape[3]
    x1 = int(round((w - tw) / 2.))
    y1 = int(round((h - th) / 2.))
    return variable[:, :, y1 : y1 + th, x1 : x1 + tw]

    
def cross_entropy_loss_RCF(prediction, label):
    ''' RCF cross entropy loss function:
    prediction: predicted sketch tensor
    label: ground truth tensor'''
    label = label.long()
    mask = label.float()
    # Calculate number of positive/negative samples from ground truth
    num_positive = torch.sum((mask==1).float()).float()
    num_negative = torch.sum((mask==0).float()).float()
    # Update mask, which is weight tensor for cross entropy function
    mask[mask == 1] = 1.0 * num_negative / (num_positive + num_negative)
    mask[mask == 0] = dft_lambda * num_positive / (num_positive + num_negative)
    mask[mask == 2] = 0
    # cross entropy function
    cost = torch.nn.functional.binary_cross_entropy(
            prediction.float(),label.float(), weight=mask, reduce=False)
    return torch.sum(cost)

class Logger(object):
    ''' Update logs related to the model'''
    def __init__(self, fpath=None):
        self.console = sys.stdout
        self.file = None
        if fpath is not None:
            self.file = open(fpath, 'w')

    def __del__(self):
        self.close()

    def __enter__(self):
        pass

    def __exit__(self, *args):
        self.close()

    def write(self, msg):
        self.console.write(msg)
        if self.file is not None:
            self.file.write(msg)

    def flush(self):
        self.console.flush()
        if self.file is not None:
            self.file.flush()
            os.fsync(self.file.fileno())

    def close(self):
        self.console.close()
        if self.file is not None:
            self.file.close()

class Averagvalue(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def save_checkpoint(state, filename='checkpoint.pth'):
    """Save pre-trained models per epoch"""
    torch.save(state, filename)


def load_vgg16pretrain(model, vggmodel='vgg16convs.mat'):
    """Update weights and bias of vgg 16 model to RCF
    model as initial weights and bias, since vgg 16 
    is the backbone of RCF"""
    vgg16 = sio.loadmat(vggmodel)
    torch_params =  model.state_dict()
    for k in vgg16.keys():
        name_par = k.split('-')
        size = len(name_par)
        # Update when there is a CNN layer
        if size  == 2:
            name_space = name_par[0] + '.' + name_par[1]
            data = np.squeeze(vgg16[k])
            torch_params[name_space] = torch.from_numpy(data)
    model.load_state_dict(torch_params)

def load_vgg19pretrain(model):
    """Update weights and bias of vgg 19 model to RCF
    model as initial weights and bias, since vgg 19 
    is the backbone of enhanced RCF"""
    vgg19 = torchvision.models.vgg19(pretrained=True)
    torch_params =  model.state_dict()
    vgg19_keys = ['conv1_1','relu','conv1_2','relu','maxpool','conv2_1','relu','conv2_2','relu','maxpool',
                  'conv3_1','relu','conv3_2','relu','conv3_3','relu','conv3_4','relu','maxpool','conv4_1',
                  'relu','conv4_2','relu','conv4_3','relu','conv4_4','relu','maxpool','conv5_1','relu',
                  'conv5_2','relu','conv5_3','relu','conv5_4','relu','maxpool']
    for k in vgg19_keys:
        # Update when there is a CNN layer
        if '_' in k:
            name_space_wt = k + '.weight'
            name_space_bs = k + '.bias'
            data_wt = vgg19.features[vgg19_keys.index(k)].weight.detach().numpy()
            data_bs = vgg19.features[vgg19_keys.index(k)].bias.detach().numpy()
            torch_params[name_space_wt] = torch.from_numpy(data_wt)
            torch_params[name_space_bs] = torch.from_numpy(data_bs)
    model.load_state_dict(torch_params)

# def load_vgg19pretrain(model):
#     """RCC version: Update weights and bias of vgg 19 model 
#     to RCF model as initial weights and bias, since vgg 19
#     is the backbone of enhanced RCF"""
#     vgg19 = torch.load(join(Root_dir, 'vgg19.pth'))
#     torch_params = model.state_dict()
#     vgg19_keys = list(vgg19.keys())[:-6]
#     model_keys = ['conv1_1','conv1_1','conv1_2','conv1_2','conv2_1','conv2_1','conv2_2','conv2_2',
#                   'conv3_1','conv3_1','conv3_2','conv3_2','conv3_3','conv3_3','conv3_4','conv3_4',
#                   'conv4_1','conv4_1','conv4_2','conv4_2','conv4_3','conv4_3','conv4_4','conv4_4',
#                   'conv5_1','conv5_1','conv5_2','conv5_2','conv5_3','conv5_3','conv5_4','conv5_4']
#     for i, k in enumerate(vgg19_keys):
#         # Update when there is a CNN layer
#         if 'weight' in k:
#             name_space_wt = model_keys[i] + '.weight'
#             data_wt = vgg19[k].detach().numpy()
#             torch_params[name_space_wt] = torch.from_numpy(data_wt)
#         if 'bias' in k:
#             name_space_bs = model_keys[i] + '.bias'
#             data_bs = vgg19[k].detach().numpy()
#             torch_params[name_space_bs] = torch.from_numpy(data_bs)
#     model.load_state_dict(torch_params)

    
def weights_init(m):
    """Function to initialize weights"""
    if isinstance(m, nn.Conv2d):
        # xavier(m.weight.data)
        m.weight.data.normal_(0, 0.01)
        if m.weight.data.shape == torch.Size([1, 5, 1, 1]):
            # for new_score_weight
            torch.nn.init.constant_(m.weight, 0.2) # as per https://github.com/yun-liu/rcf
        if m.bias is not None:
            m.bias.data.zero_()

# %% [markdown]
# ## 5. Define enhanced RCF model

# %% [markdown]
# RCF stands for Richer Convolutional Features, which encapsulates all convolutional features into more discriminative representation, which makes good usage of rich feature hierarchies, and is amenable to training via backpropagation.\
# The author of RCF model is Yun Liu and this is the link to his paper:
# https://arxiv.org/pdf/1612.02103.pdf \
# My work is also inspired by a Github page, where the authur put a Pytorch implementation of the original model: https://github.com/balajiselvaraj1601/RCF_Pytorch_Updated \
# Our enhanced RCF model has a few improvements from the original RCF model, including:
# - VGG19 backbone structure
# - tuned learning rate
# - revised cross entropy function: tuned eta and lambda parameters
# - revised activation function: LeakyRELU

# %%
class ERCF(nn.Module):
    def __init__(self):
        # Instantiate all the modules for RCF
        super().__init__()
#         super(RCF, self).__init__()
        #lr 1 2 decay 1 0
        self.conv1_1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, 3, padding=1)
        self.conv2_1 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv2_2 = nn.Conv2d(128, 128, 3, padding=1)
        
        self.conv3_1 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv3_2 = nn.Conv2d(256, 256, 3, padding=1)
        self.conv3_3 = nn.Conv2d(256, 256, 3, padding=1)
        
        self.conv3_4 = nn.Conv2d(256, 256, 3, padding=1)
        
        self.conv4_1 = nn.Conv2d(256, 512, 3, padding=1)
        self.conv4_2 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv4_3 = nn.Conv2d(512, 512, 3, padding=1)

        self.conv4_4 = nn.Conv2d(512, 512, 3, padding=1)

        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=3,
                        stride=1, padding=2, dilation=2)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=3,
                        stride=1, padding=2, dilation=2)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=3,
                        stride=1, padding=2, dilation=2)
        
        self.conv5_4 = nn.Conv2d(512, 512, kernel_size=3,
                        stride=1, padding=2, dilation=2)
        self.LeakyReLU = nn.LeakyReLU()
        self.maxpool = nn.MaxPool2d(2, stride=2, ceil_mode=True)
        self.maxpool4 = nn.MaxPool2d(2, stride=1, ceil_mode=True)


        #lr 0.1 0.2 decay 1 0
        self.conv1_1_down = nn.Conv2d(64, 21, 1, padding=0)
        self.conv1_2_down = nn.Conv2d(64, 21, 1, padding=0)
        self.conv2_1_down = nn.Conv2d(128, 21, 1, padding=0)
        self.conv2_2_down = nn.Conv2d(128, 21, 1, padding=0)

        self.conv3_1_down = nn.Conv2d(256, 21, 1, padding=0)
        self.conv3_2_down = nn.Conv2d(256, 21, 1, padding=0)
        self.conv3_3_down = nn.Conv2d(256, 21, 1, padding=0)
        
        self.conv3_4_down = nn.Conv2d(256, 21, 1, padding=0)
        
        self.conv4_1_down = nn.Conv2d(512, 21, 1, padding=0)
        self.conv4_2_down = nn.Conv2d(512, 21, 1, padding=0)
        self.conv4_3_down = nn.Conv2d(512, 21, 1, padding=0)
        
        self.conv4_4_down = nn.Conv2d(512, 21, 1, padding=0)
        
        self.conv5_1_down = nn.Conv2d(512, 21, 1, padding=0)
        self.conv5_2_down = nn.Conv2d(512, 21, 1, padding=0)
        self.conv5_3_down = nn.Conv2d(512, 21, 1, padding=0)
        
        self.conv5_4_down = nn.Conv2d(512, 21, 1, padding=0)
        
        #lr 0.01 0.02 decay 1 0
        self.score_dsn1 = nn.Conv2d(21, 1, 1)
        self.score_dsn2 = nn.Conv2d(21, 1, 1)
        self.score_dsn3 = nn.Conv2d(21, 1, 1)
        self.score_dsn4 = nn.Conv2d(21, 1, 1)
        self.score_dsn5 = nn.Conv2d(21, 1, 1)
        #lr 0.001 0.002 decay 1 0
        self.score_final = nn.Conv2d(5, 1, 1)

    def forward(self, x):
        # The forward function defines the network structure
        # and how to get the output of the neural net
        img_H, img_W = x.shape[2], x.shape[3]
        conv1_1 = self.LeakyReLU(self.conv1_1(x))
        conv1_2 = self.LeakyReLU(self.conv1_2(conv1_1))
        pool1   = self.maxpool(conv1_2)

        conv2_1 = self.LeakyReLU(self.conv2_1(pool1))
        conv2_2 = self.LeakyReLU(self.conv2_2(conv2_1))
        pool2   = self.maxpool(conv2_2)

        conv3_1 = self.LeakyReLU(self.conv3_1(pool2))
        conv3_2 = self.LeakyReLU(self.conv3_2(conv3_1))
        conv3_3 = self.LeakyReLU(self.conv3_3(conv3_2))
        
        conv3_4 = self.LeakyReLU(self.conv3_4(conv3_3))
        pool3   = self.maxpool(conv3_4)

        conv4_1 = self.LeakyReLU(self.conv4_1(pool3))
        conv4_2 = self.LeakyReLU(self.conv4_2(conv4_1))
        conv4_3 = self.LeakyReLU(self.conv4_3(conv4_2))
        
        conv4_4 = self.LeakyReLU(self.conv4_4(conv4_3))
        pool4   = self.maxpool4(conv4_4)

        conv5_1 = self.LeakyReLU(self.conv5_1(pool4))
        conv5_2 = self.LeakyReLU(self.conv5_2(conv5_1))
        conv5_3 = self.LeakyReLU(self.conv5_3(conv5_2))
        
        conv5_4 = self.LeakyReLU(self.conv5_4(conv5_3))
        
        conv1_1_down = self.conv1_1_down(conv1_1)
        conv1_2_down = self.conv1_2_down(conv1_2)
        conv2_1_down = self.conv2_1_down(conv2_1)
        conv2_2_down = self.conv2_2_down(conv2_2)
        conv3_1_down = self.conv3_1_down(conv3_1)
        conv3_2_down = self.conv3_2_down(conv3_2)
        conv3_3_down = self.conv3_3_down(conv3_3)
        
        conv3_4_down = self.conv3_4_down(conv3_4)
        
        conv4_1_down = self.conv4_1_down(conv4_1)
        conv4_2_down = self.conv4_2_down(conv4_2)
        conv4_3_down = self.conv4_3_down(conv4_3)
        
        conv4_4_down = self.conv4_4_down(conv4_4)
        
        conv5_1_down = self.conv5_1_down(conv5_1)
        conv5_2_down = self.conv5_2_down(conv5_2)
        conv5_3_down = self.conv5_3_down(conv5_3)
        
        conv5_4_down = self.conv5_4_down(conv5_4)
        
        so1_out = self.score_dsn1(conv1_1_down + conv1_2_down)
        so2_out = self.score_dsn2(conv2_1_down + conv2_2_down)
        so3_out = self.score_dsn3(conv3_1_down + conv3_2_down + conv3_3_down + conv3_4_down)
        so4_out = self.score_dsn4(conv4_1_down + conv4_2_down + conv4_3_down + conv4_4_down)
        so5_out = self.score_dsn5(conv5_1_down + conv5_2_down + conv5_3_down + conv5_4_down)
        ## transpose and crop way 
        weight_deconv2 =  make_bilinear_weights(4, 1).cuda() # cuda method is to move tensors and models from cpu to gpu
        weight_deconv3 =  make_bilinear_weights(8, 1).cuda()
        weight_deconv4 =  make_bilinear_weights(16, 1).cuda()
        weight_deconv5 =  make_bilinear_weights(16, 1).cuda()

        upsample2 = torch.nn.functional.conv_transpose2d(so2_out, weight_deconv2, stride=2)
        upsample3 = torch.nn.functional.conv_transpose2d(so3_out, weight_deconv3, stride=4)
        upsample4 = torch.nn.functional.conv_transpose2d(so4_out, weight_deconv4, stride=8)
        upsample5 = torch.nn.functional.conv_transpose2d(so5_out, weight_deconv5, stride=8)
        ### center crop
        so1 = crop(so1_out, img_H, img_W)
        so2 = crop(upsample2, img_H, img_W)
        so3 = crop(upsample3, img_H, img_W)
        so4 = crop(upsample4, img_H, img_W)
        so5 = crop(upsample5, img_H, img_W)

        fusecat = torch.cat((so1, so2, so3, so4, so5), dim=1)
        fuse = self.score_final(fusecat)
        results = [so1, so2, so3, so4, so5, fuse]
        results = [torch.sigmoid(r) for r in results]
        return results

# %% [markdown]
# ## 6. Define train and test functions

# %%
def train(train_loader, model, optimizer, epoch, save_dir):
    batch_time = Averagvalue()
    data_time = Averagvalue()
    losses = Averagvalue()
    # switch to train mode
    model.train()
    end = time.time()
    epoch_loss = []
    counter = 0
    for i, (image, label) in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        image, label = image.cuda(), label.cuda()
        outputs = model(image)
        loss = torch.zeros(1).cuda()
        for o in outputs:
            loss = loss + cross_entropy_loss_RCF(o, label)
        counter += 1
        loss = loss / dft_is
        loss.backward() # back propagation
        # Gradient descent every dft_is, which is iteration size
        if counter == dft_is:
            # Perform a single optimization step
            optimizer.step()
            # Set the gradients of all optimized torch.Tensor s to zero
            optimizer.zero_grad()
            counter = 0
        # measure accuracy and record loss
        losses.update(loss.item(), image.size(0))
        epoch_loss.append(loss.item())
        batch_time.update(time.time() - end)
        end = time.time()
        # display and logging
        if not isdir(save_dir):
            os.makedirs(save_dir)
        # Print log and save outputs every frequency, which by default is 1000
        if i % dft_freq == 0:
            info = 'Epoch: [{0}/{1}][{2}/{3}] '.format(epoch, dft_maxep - 1, i, len(train_loader)) + \
                   'Time {batch_time.val:.3f} (avg:{batch_time.avg:.3f}) '.format(batch_time=batch_time) + \
                   'Loss {loss.val:f} (avg:{loss.avg:f}) '.format(
                       loss=losses)
            print(info)
            # label_out is edge with label having pixel equals to 1
            label_out = torch.eq(label, 1).float()
            # append label_out to outputs
            outputs.append(label_out)
            _, _, H, W = outputs[0].shape # H W: predicted sketch height and width
            all_results = torch.zeros((len(outputs), 1, H, W))
            for j in range(len(outputs)):
                # Reduce dimensions from 4d tensor to 2d tensor
                all_results[j, 0, :, :] = outputs[j][0, 0, :, :]
            torchvision.utils.save_image(1-all_results, join(save_dir, "iter-%d.jpg" % i))
    return losses.avg, epoch_loss

def validation_loss(val_loader, model, optimizer, epoch):
    model.eval()
    losses = Averagvalue()
    epoch_loss = []
    counter = 0
    for i, (image, label) in enumerate(val_loader):
        image, label = image.cuda(), label.cuda()
        outputs = model(image)
        loss = torch.zeros(1).cuda()
        for o in outputs:
            loss = loss + cross_entropy_loss_RCF(o, label)
        counter += 1
        loss = loss / dft_is
        loss.backward() # back propagation
        # Gradient descent every dft_is, which is iteration size
        if counter == dft_is:
            # Perform a single optimization step
            optimizer.step()
            # Set the gradients of all optimized torch.Tensor s to zero
            optimizer.zero_grad()
            counter = 0
        # measure accuracy and record loss
        losses.update(loss.item(), image.size(0))
        epoch_loss.append(loss.item())
    return losses.avg, epoch_loss


def multiscale_test(model, test_loader, epoch, test_list, save_dir):
    model.eval()
    if not isdir(save_dir):
        os.makedirs(save_dir + ('-black'))
        os.makedirs(save_dir + ('-white'))
        os.makedirs(save_dir + ('-graduate'))
    scale = [0.5, 1, 1.5]
    for idx, image in enumerate(test_loader):
        filename = splitext(test_list[idx])[0]
        image = image[0]
        image_in = image.numpy().transpose((1,2,0))
        _, H, W = image.shape
        multi_fuse = np.zeros((H, W), np.float32)
        for k in range(0, len(scale)):
            im_ = cv2.resize(image_in, None, fx=scale[k], fy=scale[k], interpolation=cv2.INTER_LINEAR)
            im_ = im_.transpose((2,0,1))
            results = model(torch.unsqueeze(torch.from_numpy(im_).cuda(), 0))
            result = torch.squeeze(results[-1].detach()).cpu().numpy()
            if k == 1:
                results_all = torch.zeros((len(results), 1, H, W))
                for i in range(len(results)):
                    results_all[i, 0, :, :] = results[i]
                torchvision.utils.save_image(1-results_all, join(save_dir + ('-graduate'), "%s.png" % filename))
            fuse = cv2.resize(result, (W, H), interpolation=cv2.INTER_LINEAR)
            multi_fuse += fuse
        multi_fuse = multi_fuse / len(scale)
        # White background
        result_out = Image.fromarray(((1-multi_fuse) * 255).astype(np.uint8))
        result_out.save(join(save_dir + ('-white'), "%s.jpg" % filename))
        # Black background
        result_out_test = Image.fromarray((multi_fuse * 255).astype(np.uint8))
        result_out_test.save(join(save_dir + ('-black'), "%s.png" % filename))

# %% [markdown]
# ## 7. Define and execute main function

# %%
def main():
    # Set up train validation split parameters
    validation_split = 0.2
    shuffle_dataset = True
    random_seed= 42

    filelist = join(data_folder, 'train_pair.lst')
    # loop thru whole list of images and labels
    with open(filelist, 'r') as f:
        filelist = f.readlines()
    # Create data indices for training and validation splits
    dataset_size = len(filelist)
    indices = list(range(dataset_size))
    split_idx = int(np.floor(validation_split * dataset_size))
    if shuffle_dataset:
        np.random.seed(random_seed)
        np.random.shuffle(indices)
    train_indices, val_indices = indices[split_idx:], indices[:split_idx]

    # Creating data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    valid_sampler = SubsetRandomSampler(val_indices)
    train_dataset = BSDS_Dataloader(root=dft_datap, split= "train")
    test_dataset = BSDS_Dataloader(root=dft_datap,  split= "test")
    train_loader = DataLoader(
    train_dataset, batch_size=dft_bs, sampler=train_sampler,
    num_workers=0, drop_last=True)
    val_loader = DataLoader(
    train_dataset, batch_size=dft_bs, sampler=valid_sampler,
    num_workers=0, drop_last=True)
    test_loader = DataLoader(
        test_dataset, batch_size=dft_bs,
        num_workers=0, drop_last=True,shuffle=False)
    with open(test_lst, 'r') as f:
        test_list = f.readlines()
    test_list = [split(i.rstrip())[1] for i in test_list]
    assert len(test_list) == len(test_loader), "%d vs %d" % (len(test_list), len(test_loader))

    # model
    model = ERCF()
    model.cuda()
    model.apply(weights_init) # Initialize weights
#     load_vgg16pretrain(model) # Update weights for each CNN layer based on VGG16 model
    load_vgg19pretrain(model) # Update weights for each CNN layer based on VGG19 model

    
    # Create optimizer to tune learning rate
    # for layers at the same step
    net_parameters_id = {}
    net = model
    for pname, p in net.named_parameters():
        if pname in ['conv1_1.weight','conv1_2.weight','conv3_4.weight',
                     'conv2_1.weight','conv2_2.weight','conv4_4.weight',
                     'conv3_1.weight','conv3_2.weight','conv3_3.weight',
                     'conv4_1.weight','conv4_2.weight','conv4_3.weight']:
            # print(pname, 'lr:1 de:1')
            if 'conv1-4.weight' not in net_parameters_id:
                net_parameters_id['conv1-4.weight'] = []
            net_parameters_id['conv1-4.weight'].append(p)
        elif pname in ['conv1_1.bias','conv1_2.bias','conv3_4.bias',
                       'conv2_1.bias','conv2_2.bias','conv4_4.bias',
                       'conv3_1.bias','conv3_2.bias','conv3_3.bias',
                       'conv4_1.bias','conv4_2.bias','conv4_3.bias']:
            # print(pname, 'lr:2 de:0')
            if 'conv1-4.bias' not in net_parameters_id:
                net_parameters_id['conv1-4.bias'] = []
            net_parameters_id['conv1-4.bias'].append(p)
        elif pname in ['conv5_1.weight','conv5_2.weight','conv5_3.weight','conv5_4.weight']:
            # print(pname, 'lr:100 de:1')
            if 'conv5.weight' not in net_parameters_id:
                net_parameters_id['conv5.weight'] = []
            net_parameters_id['conv5.weight'].append(p)
        elif pname in ['conv5_1.bias','conv5_2.bias','conv5_3.bias','conv5_4.bias'] :
            # print(pname, 'lr:200 de:0')
            if 'conv5.bias' not in net_parameters_id:
                net_parameters_id['conv5.bias'] = []
            net_parameters_id['conv5.bias'].append(p)
        elif pname in ['conv1_1_down.weight','conv1_2_down.weight','conv3_4_down.weight',
                       'conv2_1_down.weight','conv2_2_down.weight','conv4_4_down.weight',
                       'conv3_1_down.weight','conv3_2_down.weight','conv3_3_down.weight',
                       'conv4_1_down.weight','conv4_2_down.weight','conv4_3_down.weight',
                       'conv5_1_down.weight','conv5_2_down.weight','conv5_3_down.weight','conv5_4_down.weight']:
            # print(pname, 'lr:0.1 de:1')
            if 'conv_down_1-5.weight' not in net_parameters_id:
                net_parameters_id['conv_down_1-5.weight'] = []
            net_parameters_id['conv_down_1-5.weight'].append(p)
        elif pname in ['conv1_1_down.bias','conv1_2_down.bias','conv3_4_down.bias',
                       'conv2_1_down.bias','conv2_2_down.bias','conv4_4_down.bias',
                       'conv3_1_down.bias','conv3_2_down.bias','conv3_3_down.bias',
                       'conv4_1_down.bias','conv4_2_down.bias','conv4_3_down.bias',
                       'conv5_1_down.bias','conv5_2_down.bias','conv5_3_down.bias','conv5_4_down.bias']:
            # print(pname, 'lr:0.2 de:0')
            if 'conv_down_1-5.bias' not in net_parameters_id:
                net_parameters_id['conv_down_1-5.bias'] = []
            net_parameters_id['conv_down_1-5.bias'].append(p)
        elif pname in ['score_dsn1.weight','score_dsn2.weight','score_dsn3.weight',
                       'score_dsn4.weight','score_dsn5.weight']:
            # print(pname, 'lr:0.01 de:1')
            if 'score_dsn_1-5.weight' not in net_parameters_id:
                net_parameters_id['score_dsn_1-5.weight'] = []
            net_parameters_id['score_dsn_1-5.weight'].append(p)
        elif pname in ['score_dsn1.bias','score_dsn2.bias','score_dsn3.bias',
                       'score_dsn4.bias','score_dsn5.bias']:
            # print(pname, 'lr:0.02 de:0')
            if 'score_dsn_1-5.bias' not in net_parameters_id:
                net_parameters_id['score_dsn_1-5.bias'] = []
            net_parameters_id['score_dsn_1-5.bias'].append(p)
        elif pname in ['score_final.weight']:
            # print(pname, 'lr:0.001 de:1')
            if 'score_final.weight' not in net_parameters_id:
                net_parameters_id['score_final.weight'] = []
            net_parameters_id['score_final.weight'].append(p)
        elif pname in ['score_final.bias']:
            # print(pname, 'lr:0.002 de:0')
            if 'score_final.bias' not in net_parameters_id:
                net_parameters_id['score_final.bias'] = []
            net_parameters_id['score_final.bias'].append(p)

    optimizer = torch.optim.SGD([
            {'params': net_parameters_id['conv1-4.weight']      , 'lr': dft_lr*1    , 'weight_decay': dft_wd},
            {'params': net_parameters_id['conv1-4.bias']        , 'lr': dft_lr*2    , 'weight_decay': 0.},
            {'params': net_parameters_id['conv5.weight']        , 'lr': dft_lr*100  , 'weight_decay': dft_wd},
            {'params': net_parameters_id['conv5.bias']          , 'lr': dft_lr*200  , 'weight_decay': 0.},
            {'params': net_parameters_id['conv_down_1-5.weight'], 'lr': dft_lr*0.1  , 'weight_decay': dft_wd},
            {'params': net_parameters_id['conv_down_1-5.bias']  , 'lr': dft_lr*0.2  , 'weight_decay': 0.},
            {'params': net_parameters_id['score_dsn_1-5.weight'], 'lr': dft_lr*0.01 , 'weight_decay': dft_wd},
            {'params': net_parameters_id['score_dsn_1-5.bias']  , 'lr': dft_lr*0.02 , 'weight_decay': 0.},
            {'params': net_parameters_id['score_final.weight']  , 'lr': dft_lr*0.001, 'weight_decay': dft_wd},
            {'params': net_parameters_id['score_final.bias']    , 'lr': dft_lr*0.002, 'weight_decay': 0.},
        ], lr=dft_lr, momentum=dft_mmtum, weight_decay=dft_wd)
    # Decays the learning rate of each parameter group by gamma 
    # every step_size epochs
    scheduler = lr_scheduler.StepLR(optimizer, step_size=dft_ss, gamma=dft_gm)
    
    # log
    log = Logger(join(tmp_dir, '%s-%d-log.txt' %('sgd',dft_lr)))
    sys.stdout = log
    
    global train_loss, train_loss_detail, val_loss, val_loss_detail
    # train/val loss parameters
    train_loss = []
    train_loss_detail = []
    val_loss = []
    val_loss_detail = []
    for epoch in range(dft_step, dft_maxep):
        if epoch == 1:
            multiscale_test(model, test_loader, epoch=epoch, test_list=test_list,
                 save_dir = join(tmp_dir, 'initial-testing-record'))
        # Train the model
        tr_avg_loss, tr_detail_loss = train(
            train_loader, model, optimizer, epoch,
            save_dir = join(tmp_dir, 'epoch-%d-training-record' % epoch))
        # Collect validation loss
        val_avg_loss, val_detail_loss = validation_loss(
            val_loader, model, optimizer, epoch)
        # Predict test sketch
        multiscale_test(model, test_loader, epoch=epoch, test_list=test_list,
            save_dir = join(tmp_dir, 'epoch-%d-testing-record' % epoch))
        log.flush() # write log
        # Save checkpoint
        save_file = os.path.join(tmp_dir, 'checkpoint_epoch{}.pth'.format(epoch))
        save_checkpoint({
            'epoch': epoch,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict()
                         }, filename=save_file)
        scheduler.step() # will adjust learning rate
        # save train/val loss
        train_loss.append(tr_avg_loss)
        train_loss_detail += tr_detail_loss
        val_loss.append(val_avg_loss)
        val_loss_detail += val_detail_loss

if __name__ == '__main__':
    main()
# Out:
# /home/ygao26/.local/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /home/ygao26/.local/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Epoch: [1/10][0/23040] Time 0.291 (avg:0.291) Loss 0.000000 (avg:0.000000)
# Epoch: [1/10][1000/23040] Time 0.064 (avg:0.077) Loss 65.875763 (avg:94.228068)
# Epoch: [1/10][2000/23040] Time 0.101 (avg:0.077) Loss 117.368294 (avg:85.390444)
# Epoch: [1/10][3000/23040] Time 0.018 (avg:0.076) Loss 0.856411 (avg:80.657080)
# Epoch: [1/10][4000/23040] Time 0.067 (avg:0.076) Loss 65.037842 (avg:78.828373)
# Epoch: [1/10][5000/23040] Time 0.121 (avg:0.076) Loss 39.945950 (avg:77.778404)
# Epoch: [1/10][6000/23040] Time 0.029 (avg:0.076) Loss 0.574963 (avg:76.081058)
# Epoch: [1/10][7000/23040] Time 0.076 (avg:0.075) Loss 76.181015 (avg:74.615105)
# Epoch: [1/10][8000/23040] Time 0.099 (avg:0.075) Loss 67.824684 (avg:73.125382)
# Epoch: [1/10][9000/23040] Time 0.040 (avg:0.075) Loss 0.871823 (avg:72.279450)
# Epoch: [1/10][10000/23040] Time 0.085 (avg:0.074) Loss 63.360443 (avg:71.471799)
# Epoch: [1/10][11000/23040] Time 0.104 (avg:0.074) Loss 182.703262 (avg:70.695135)
# Epoch: [1/10][12000/23040] Time 0.060 (avg:0.074) Loss 0.082029 (avg:69.667987)
# Epoch: [1/10][13000/23040] Time 0.086 (avg:0.073) Loss 196.273056 (avg:69.184452)
# Epoch: [1/10][14000/23040] Time 0.096 (avg:0.073) Loss 36.524269 (avg:68.863072)
# Epoch: [1/10][15000/23040] Time 0.021 (avg:0.073) Loss 0.000000 (avg:68.426588)
# Epoch: [1/10][16000/23040] Time 0.092 (avg:0.072) Loss 46.441994 (avg:67.960131)
# Epoch: [1/10][17000/23040] Time 0.067 (avg:0.072) Loss 25.095982 (avg:67.757499)
# Epoch: [1/10][18000/23040] Time 0.036 (avg:0.072) Loss 3.625968 (avg:67.404334)
# Epoch: [1/10][19000/23040] Time 0.081 (avg:0.071) Loss 72.569992 (avg:67.229127)
# Epoch: [1/10][20000/23040] Time 0.085 (avg:0.071) Loss 45.672985 (avg:66.911085)
# Epoch: [1/10][21000/23040] Time 0.032 (avg:0.071) Loss 0.210023 (avg:66.540541)
# Epoch: [1/10][22000/23040] Time 0.064 (avg:0.070) Loss 39.326405 (avg:66.167731)
# Epoch: [1/10][23000/23040] Time 0.039 (avg:0.070) Loss 0.127116 (avg:65.854906)
# Epoch: [2/10][0/23040] Time 0.096 (avg:0.096) Loss 0.000000 (avg:0.000000)
# Epoch: [2/10][1000/23040] Time 0.063 (avg:0.043) Loss 27.024513 (avg:56.912835)
# Epoch: [2/10][2000/23040] Time 0.030 (avg:0.044) Loss 54.211128 (avg:57.569065)
# Epoch: [2/10][3000/23040] Time 0.076 (avg:0.044) Loss 39.534794 (avg:56.968976)
# Epoch: [2/10][4000/23040] Time 0.041 (avg:0.044) Loss 28.042339 (avg:57.052576)
# Epoch: [2/10][5000/23040] Time 0.031 (avg:0.044) Loss 56.398376 (avg:57.378025)
# Epoch: [2/10][6000/23040] Time 0.075 (avg:0.044) Loss 24.368076 (avg:57.381134)
# Epoch: [2/10][7000/23040] Time 0.030 (avg:0.044) Loss 11.022408 (avg:57.230109)
# Epoch: [2/10][8000/23040] Time 0.023 (avg:0.044) Loss 0.000000 (avg:57.392278)
# Epoch: [2/10][9000/23040] Time 0.047 (avg:0.044) Loss 220.083359 (avg:57.650780)
# Epoch: [2/10][10000/23040] Time 0.015 (avg:0.044) Loss 1.687747 (avg:57.515412)
# Epoch: [2/10][11000/23040] Time 0.048 (avg:0.044) Loss 131.782349 (avg:57.445723)
# Epoch: [2/10][12000/23040] Time 0.020 (avg:0.044) Loss 1.857304 (avg:57.634090)
# Epoch: [2/10][13000/23040] Time 0.090 (avg:0.044) Loss 52.573215 (avg:57.362094)
# Epoch: [2/10][14000/23040] Time 0.060 (avg:0.044) Loss 78.300674 (avg:57.360594)
# Epoch: [2/10][15000/23040] Time 0.063 (avg:0.044) Loss 35.842438 (avg:57.128948)
# Epoch: [2/10][16000/23040] Time 0.090 (avg:0.044) Loss 69.420204 (avg:57.064077)
# Epoch: [2/10][17000/23040] Time 0.031 (avg:0.044) Loss 97.881630 (avg:56.848528)
# Epoch: [2/10][18000/23040] Time 0.017 (avg:0.044) Loss 2.498670 (avg:56.924375)
# Epoch: [2/10][19000/23040] Time 0.030 (avg:0.044) Loss 70.941711 (avg:56.723711)
# Epoch: [2/10][20000/23040] Time 0.017 (avg:0.044) Loss 5.574747 (avg:56.685835)
# Epoch: [2/10][21000/23040] Time 0.029 (avg:0.044) Loss 38.399441 (avg:56.559838)
# Epoch: [2/10][22000/23040] Time 0.030 (avg:0.044) Loss 70.533043 (avg:56.560834)
# Epoch: [2/10][23000/23040] Time 0.060 (avg:0.044) Loss 93.518547 (avg:56.301886)
# Epoch: [3/10][0/23040] Time 0.056 (avg:0.056) Loss 93.246872 (avg:93.246872)
# Epoch: [3/10][1000/23040] Time 0.055 (avg:0.044) Loss 53.545029 (avg:53.868501)
# Epoch: [3/10][2000/23040] Time 0.030 (avg:0.044) Loss 33.502537 (avg:53.463697)
# Epoch: [3/10][3000/23040] Time 0.063 (avg:0.044) Loss 38.893185 (avg:53.549528)
# Epoch: [3/10][4000/23040] Time 0.041 (avg:0.044) Loss 30.726013 (avg:53.585644)
# Epoch: [3/10][5000/23040] Time 0.039 (avg:0.044) Loss 32.327442 (avg:53.493096)
# Epoch: [3/10][6000/23040] Time 0.039 (avg:0.044) Loss 34.290901 (avg:53.692936)
# Epoch: [3/10][7000/23040] Time 0.075 (avg:0.044) Loss 75.008438 (avg:54.153327)
# Epoch: [3/10][8000/23040] Time 0.128 (avg:0.044) Loss 247.252213 (avg:54.134253)
# Epoch: [3/10][9000/23040] Time 0.017 (avg:0.044) Loss 1.255520 (avg:53.849236)
# Epoch: [3/10][10000/23040] Time 0.018 (avg:0.044) Loss 0.000000 (avg:53.951644)
# Epoch: [3/10][11000/23040] Time 0.030 (avg:0.044) Loss 84.633469 (avg:53.892870)
# Epoch: [3/10][12000/23040] Time 0.018 (avg:0.044) Loss 3.625060 (avg:54.051877)
# Epoch: [3/10][13000/23040] Time 0.018 (avg:0.044) Loss 1.157542 (avg:53.978513)
# Epoch: [3/10][14000/23040] Time 0.018 (avg:0.044) Loss 1.126805 (avg:53.766787)
# Epoch: [3/10][15000/23040] Time 0.018 (avg:0.044) Loss 0.892828 (avg:53.690127)
# Epoch: [3/10][16000/23040] Time 0.038 (avg:0.044) Loss 32.713104 (avg:53.760047)
# Epoch: [3/10][17000/23040] Time 0.030 (avg:0.044) Loss 39.869125 (avg:53.777756)
# Epoch: [3/10][18000/23040] Time 0.041 (avg:0.044) Loss 60.503117 (avg:53.714913)
# Epoch: [3/10][19000/23040] Time 0.053 (avg:0.044) Loss 29.999573 (avg:53.618437)
# Epoch: [3/10][20000/23040] Time 0.023 (avg:0.044) Loss 0.111600 (avg:53.585885)
# Epoch: [3/10][21000/23040] Time 0.063 (avg:0.044) Loss 47.106701 (avg:53.477419)
# Epoch: [3/10][22000/23040] Time 0.053 (avg:0.044) Loss 134.518417 (avg:53.456456)
# Epoch: [3/10][23000/23040] Time 0.063 (avg:0.044) Loss 26.743246 (avg:53.456586)
# Epoch: [4/10][0/23040] Time 0.045 (avg:0.045) Loss 48.113247 (avg:48.113247)
# Epoch: [4/10][1000/23040] Time 0.075 (avg:0.044) Loss 89.943214 (avg:52.129098)
# Epoch: [4/10][2000/23040] Time 0.030 (avg:0.044) Loss 17.485991 (avg:50.912967)
# Epoch: [4/10][3000/23040] Time 0.016 (avg:0.044) Loss 3.169901 (avg:50.574630)
# Epoch: [4/10][4000/23040] Time 0.020 (avg:0.044) Loss 0.989678 (avg:50.857277)
# Epoch: [4/10][5000/23040] Time 0.020 (avg:0.044) Loss 1.303147 (avg:51.321077)
# Epoch: [4/10][6000/23040] Time 0.031 (avg:0.044) Loss 0.098462 (avg:51.564227)
# Epoch: [4/10][7000/23040] Time 0.063 (avg:0.044) Loss 150.810760 (avg:51.623079)
# Epoch: [4/10][8000/23040] Time 0.020 (avg:0.044) Loss 1.831460 (avg:51.479010)
# Epoch: [4/10][9000/23040] Time 0.023 (avg:0.044) Loss 0.686689 (avg:51.803428)
# Epoch: [4/10][10000/23040] Time 0.039 (avg:0.044) Loss 30.950697 (avg:51.825412)
# Epoch: [4/10][11000/23040] Time 0.020 (avg:0.044) Loss 0.000000 (avg:51.955373)
# Epoch: [4/10][12000/23040] Time 0.053 (avg:0.044) Loss 113.997177 (avg:51.968003)
# Epoch: [4/10][13000/23040] Time 0.030 (avg:0.044) Loss 84.002403 (avg:51.934326)
# Epoch: [4/10][14000/23040] Time 0.017 (avg:0.044) Loss 1.939840 (avg:51.753235)
# Epoch: [4/10][15000/23040] Time 0.030 (avg:0.044) Loss 118.053940 (avg:51.804621)
# Epoch: [4/10][16000/23040] Time 0.017 (avg:0.044) Loss 1.816213 (avg:51.625501)
# Epoch: [4/10][17000/23040] Time 0.020 (avg:0.044) Loss 0.125683 (avg:51.456767)
# Epoch: [4/10][18000/23040] Time 0.018 (avg:0.044) Loss 1.859206 (avg:51.295409)
# Epoch: [4/10][19000/23040] Time 0.031 (avg:0.044) Loss 0.425385 (avg:51.437872)
# Epoch: [4/10][20000/23040] Time 0.053 (avg:0.044) Loss 25.860289 (avg:51.444295)
# Epoch: [4/10][21000/23040] Time 0.041 (avg:0.044) Loss 31.707054 (avg:51.423477)
# Epoch: [4/10][22000/23040] Time 0.053 (avg:0.044) Loss 9.865144 (avg:51.447537)
# Epoch: [4/10][23000/23040] Time 0.053 (avg:0.044) Loss 14.037013 (avg:51.304738)
# Epoch: [5/10][0/23040] Time 0.127 (avg:0.127) Loss 29.835886 (avg:29.835886)
# Epoch: [5/10][1000/23040] Time 0.048 (avg:0.044) Loss 26.888315 (avg:50.701206)
# Epoch: [5/10][2000/23040] Time 0.030 (avg:0.045) Loss 37.880219 (avg:52.033811)
# Epoch: [5/10][3000/23040] Time 0.060 (avg:0.045) Loss 31.655165 (avg:51.309324)
# Epoch: [5/10][4000/23040] Time 0.016 (avg:0.044) Loss 0.448468 (avg:50.925468)
# Epoch: [5/10][5000/23040] Time 0.018 (avg:0.044) Loss 1.016265 (avg:50.782865)
# Epoch: [5/10][6000/23040] Time 0.041 (avg:0.044) Loss 75.619659 (avg:50.356177)
# Epoch: [5/10][7000/23040] Time 0.030 (avg:0.044) Loss 40.739109 (avg:50.813525)
# Epoch: [5/10][8000/23040] Time 0.018 (avg:0.044) Loss 0.376175 (avg:50.916181)
# Epoch: [5/10][9000/23040] Time 0.063 (avg:0.044) Loss 29.309853 (avg:51.020156)
# Epoch: [5/10][10000/23040] Time 0.060 (avg:0.044) Loss 104.245087 (avg:51.122980)
# Epoch: [5/10][11000/23040] Time 0.017 (avg:0.044) Loss 0.936229 (avg:51.288618)
# Epoch: [5/10][12000/23040] Time 0.017 (avg:0.044) Loss 0.972867 (avg:51.186841)
# Epoch: [5/10][13000/23040] Time 0.053 (avg:0.044) Loss 47.774921 (avg:51.336591)
# Epoch: [5/10][14000/23040] Time 0.060 (avg:0.044) Loss 53.848545 (avg:51.226457)
# Epoch: [5/10][15000/23040] Time 0.041 (avg:0.044) Loss 103.585403 (avg:50.965376)
# Epoch: [5/10][16000/23040] Time 0.020 (avg:0.044) Loss 0.771186 (avg:51.002472)
# Epoch: [5/10][17000/23040] Time 0.017 (avg:0.044) Loss 2.233443 (avg:50.910463)
# Epoch: [5/10][18000/23040] Time 0.030 (avg:0.044) Loss 158.550201 (avg:50.805763)
# Epoch: [5/10][19000/23040] Time 0.020 (avg:0.044) Loss 0.000000 (avg:51.005902)
# Epoch: [5/10][20000/23040] Time 0.030 (avg:0.044) Loss 41.722767 (avg:50.891840)
# Epoch: [5/10][21000/23040] Time 0.055 (avg:0.044) Loss 48.426609 (avg:50.827492)
# Epoch: [5/10][22000/23040] Time 0.048 (avg:0.044) Loss 187.936874 (avg:50.902692)
# Epoch: [5/10][23000/23040] Time 0.053 (avg:0.044) Loss 34.466827 (avg:50.877165)
# Epoch: [6/10][0/23040] Time 0.068 (avg:0.068) Loss 51.645168 (avg:51.645168)
# Epoch: [6/10][1000/23040] Time 0.030 (avg:0.044) Loss 62.592308 (avg:52.648647)
# Epoch: [6/10][2000/23040] Time 0.018 (avg:0.044) Loss 1.217554 (avg:51.280254)
# Epoch: [6/10][3000/23040] Time 0.020 (avg:0.044) Loss 0.537764 (avg:50.361233)
# Epoch: [6/10][4000/23040] Time 0.053 (avg:0.044) Loss 151.134598 (avg:50.719375)
# Epoch: [6/10][5000/23040] Time 0.063 (avg:0.044) Loss 38.242695 (avg:50.507219)
# Epoch: [6/10][6000/23040] Time 0.016 (avg:0.044) Loss 1.064510 (avg:50.674375)
# Epoch: [6/10][7000/23040] Time 0.017 (avg:0.044) Loss 3.500879 (avg:50.729911)
# Epoch: [6/10][8000/23040] Time 0.016 (avg:0.044) Loss 3.363472 (avg:50.942734)
# Epoch: [6/10][9000/23040] Time 0.030 (avg:0.044) Loss 21.990374 (avg:50.935492)
# Epoch: [6/10][10000/23040] Time 0.023 (avg:0.044) Loss 2.279088 (avg:50.654303)
# Epoch: [6/10][11000/23040] Time 0.075 (avg:0.044) Loss 84.456703 (avg:50.930410)
# Epoch: [6/10][12000/23040] Time 0.047 (avg:0.044) Loss 57.347309 (avg:50.932776)
# Epoch: [6/10][13000/23040] Time 0.039 (avg:0.044) Loss 25.045055 (avg:51.121546)
# Epoch: [6/10][14000/23040] Time 0.063 (avg:0.044) Loss 23.789906 (avg:51.077454)
# Epoch: [6/10][15000/23040] Time 0.119 (avg:0.044) Loss 90.618408 (avg:50.982176)
# Epoch: [6/10][16000/23040] Time 0.030 (avg:0.044) Loss 35.323872 (avg:50.989052)
# Epoch: [6/10][17000/23040] Time 0.017 (avg:0.044) Loss 1.364651 (avg:51.041639)
# Epoch: [6/10][18000/23040] Time 0.018 (avg:0.044) Loss 0.569762 (avg:50.900898)
# Epoch: [6/10][19000/23040] Time 0.017 (avg:0.044) Loss 1.708584 (avg:50.740993)
# Epoch: [6/10][20000/23040] Time 0.020 (avg:0.044) Loss 0.000000 (avg:50.769519)
# Epoch: [6/10][21000/23040] Time 0.063 (avg:0.044) Loss 118.306885 (avg:50.680277)
# Epoch: [6/10][22000/23040] Time 0.041 (avg:0.044) Loss 23.139870 (avg:50.485943)
# Epoch: [6/10][23000/23040] Time 0.128 (avg:0.044) Loss 347.682220 (avg:50.569521)
# Epoch: [7/10][0/23040] Time 0.054 (avg:0.054) Loss 89.338310 (avg:89.338310)
# Epoch: [7/10][1000/23040] Time 0.053 (avg:0.045) Loss 20.320284 (avg:50.144930)
# Epoch: [7/10][2000/23040] Time 0.062 (avg:0.045) Loss 161.275101 (avg:50.620451)
# Epoch: [7/10][3000/23040] Time 0.063 (avg:0.045) Loss 188.796616 (avg:51.079559)
# Epoch: [7/10][4000/23040] Time 0.063 (avg:0.045) Loss 54.740032 (avg:51.412936)
# Epoch: [7/10][5000/23040] Time 0.063 (avg:0.044) Loss 116.579895 (avg:51.029281)
# Epoch: [7/10][6000/23040] Time 0.039 (avg:0.044) Loss 66.778656 (avg:50.848663)
# Epoch: [7/10][7000/23040] Time 0.023 (avg:0.044) Loss 0.000000 (avg:50.470034)
# Epoch: [7/10][8000/23040] Time 0.063 (avg:0.044) Loss 47.445526 (avg:50.540782)
# Epoch: [7/10][9000/23040] Time 0.064 (avg:0.044) Loss 62.402840 (avg:50.207784)
# Epoch: [7/10][10000/23040] Time 0.060 (avg:0.044) Loss 112.798737 (avg:50.039115)
# Epoch: [7/10][11000/23040] Time 0.075 (avg:0.044) Loss 44.691448 (avg:49.976277)
# Epoch: [7/10][12000/23040] Time 0.017 (avg:0.044) Loss 3.563745 (avg:49.937807)
# Epoch: [7/10][13000/23040] Time 0.063 (avg:0.044) Loss 58.120899 (avg:50.185697)
# Epoch: [7/10][14000/23040] Time 0.092 (avg:0.044) Loss 71.551872 (avg:50.117164)
# Epoch: [7/10][15000/23040] Time 0.053 (avg:0.044) Loss 38.037441 (avg:50.137955)
# Epoch: [7/10][16000/23040] Time 0.060 (avg:0.044) Loss 46.868240 (avg:50.308786)
# Epoch: [7/10][17000/23040] Time 0.020 (avg:0.044) Loss 0.257202 (avg:50.428056)
# Epoch: [7/10][18000/23040] Time 0.063 (avg:0.044) Loss 239.245346 (avg:50.547157)
# Epoch: [7/10][19000/23040] Time 0.020 (avg:0.044) Loss 0.000000 (avg:50.556424)
# Epoch: [7/10][20000/23040] Time 0.069 (avg:0.044) Loss 348.616547 (avg:50.557902)
# Epoch: [7/10][21000/23040] Time 0.119 (avg:0.044) Loss 52.182858 (avg:50.492230)
# Epoch: [7/10][22000/23040] Time 0.018 (avg:0.044) Loss 4.044785 (avg:50.331054)
# Epoch: [7/10][23000/23040] Time 0.063 (avg:0.044) Loss 51.190723 (avg:50.312283)
# Epoch: [8/10][0/23040] Time 0.115 (avg:0.115) Loss 94.152237 (avg:94.152237)
# Epoch: [8/10][1000/23040] Time 0.030 (avg:0.043) Loss 26.583624 (avg:52.362860)
# Epoch: [8/10][2000/23040] Time 0.018 (avg:0.044) Loss 0.434364 (avg:52.075137)
# Epoch: [8/10][3000/23040] Time 0.041 (avg:0.044) Loss 38.527802 (avg:50.316916)
# Epoch: [8/10][4000/23040] Time 0.063 (avg:0.044) Loss 47.084911 (avg:50.542111)
# Epoch: [8/10][5000/23040] Time 0.075 (avg:0.044) Loss 117.409035 (avg:50.168088)
# Epoch: [8/10][6000/23040] Time 0.128 (avg:0.044) Loss 82.765938 (avg:49.901126)
# Epoch: [8/10][7000/23040] Time 0.053 (avg:0.044) Loss 35.736446 (avg:49.557703)
# Epoch: [8/10][8000/23040] Time 0.018 (avg:0.044) Loss 0.137002 (avg:49.924810)
# Epoch: [8/10][9000/23040] Time 0.030 (avg:0.044) Loss 59.788593 (avg:49.936733)
# Epoch: [8/10][10000/23040] Time 0.063 (avg:0.044) Loss 27.693474 (avg:50.012244)
# Epoch: [8/10][11000/23040] Time 0.060 (avg:0.044) Loss 17.370285 (avg:50.086216)
# Epoch: [8/10][12000/23040] Time 0.063 (avg:0.044) Loss 47.799442 (avg:50.169455)
# Epoch: [8/10][13000/23040] Time 0.060 (avg:0.044) Loss 57.519722 (avg:50.193737)
# Epoch: [8/10][14000/23040] Time 0.041 (avg:0.044) Loss 54.385307 (avg:50.448693)
# Epoch: [8/10][15000/23040] Time 0.031 (avg:0.044) Loss 0.098138 (avg:50.515268)
# Epoch: [8/10][16000/23040] Time 0.018 (avg:0.044) Loss 1.273303 (avg:50.736750)
# Epoch: [8/10][17000/23040] Time 0.020 (avg:0.044) Loss 1.544937 (avg:50.487988)
# Epoch: [8/10][18000/23040] Time 0.041 (avg:0.044) Loss 88.912643 (avg:50.434473)
# Epoch: [8/10][19000/23040] Time 0.017 (avg:0.044) Loss 3.793280 (avg:50.407093)
# Epoch: [8/10][20000/23040] Time 0.030 (avg:0.044) Loss 56.128693 (avg:50.420319)
# Epoch: [8/10][21000/23040] Time 0.017 (avg:0.044) Loss 1.207901 (avg:50.333484)
# Epoch: [8/10][22000/23040] Time 0.018 (avg:0.044) Loss 6.743570 (avg:50.237664)
# Epoch: [8/10][23000/23040] Time 0.030 (avg:0.044) Loss 36.948872 (avg:50.278361)
# Epoch: [9/10][0/23040] Time 0.079 (avg:0.079) Loss 64.575554 (avg:64.575554)
# Epoch: [9/10][1000/23040] Time 0.053 (avg:0.044) Loss 24.426477 (avg:51.857978)
# Epoch: [9/10][2000/23040] Time 0.018 (avg:0.044) Loss 0.097537 (avg:50.145753)
# Epoch: [9/10][3000/23040] Time 0.119 (avg:0.045) Loss 247.897949 (avg:52.295556)
# Epoch: [9/10][4000/23040] Time 0.018 (avg:0.044) Loss 1.369212 (avg:51.579684)
# Epoch: [9/10][5000/23040] Time 0.031 (avg:0.044) Loss 67.077759 (avg:51.527402)
# Epoch: [9/10][6000/23040] Time 0.119 (avg:0.044) Loss 89.512497 (avg:51.604845)
# Epoch: [9/10][7000/23040] Time 0.069 (avg:0.044) Loss 141.953583 (avg:51.192547)
# Epoch: [9/10][8000/23040] Time 0.017 (avg:0.044) Loss 7.610634 (avg:50.850035)
# Epoch: [9/10][9000/23040] Time 0.018 (avg:0.044) Loss 0.187944 (avg:50.729929)
# Epoch: [9/10][10000/23040] Time 0.053 (avg:0.044) Loss 27.333786 (avg:50.881511)
# Epoch: [9/10][11000/23040] Time 0.018 (avg:0.044) Loss 0.783061 (avg:50.667438)
# Epoch: [9/10][12000/23040] Time 0.053 (avg:0.044) Loss 71.788651 (avg:50.306516)
# Epoch: [9/10][13000/23040] Time 0.053 (avg:0.044) Loss 25.387556 (avg:50.368590)
# Epoch: [9/10][14000/23040] Time 0.018 (avg:0.044) Loss 6.462083 (avg:50.567761)
# Epoch: [9/10][15000/23040] Time 0.039 (avg:0.044) Loss 59.815369 (avg:50.297254)
# Epoch: [9/10][16000/23040] Time 0.030 (avg:0.044) Loss 55.725216 (avg:50.559052)
# Epoch: [9/10][17000/23040] Time 0.053 (avg:0.044) Loss 39.647144 (avg:50.619632)
# Epoch: [9/10][18000/23040] Time 0.053 (avg:0.044) Loss 38.436546 (avg:50.581134)
# Epoch: [9/10][19000/23040] Time 0.054 (avg:0.044) Loss 91.463112 (avg:50.534146)
# Epoch: [9/10][20000/23040] Time 0.064 (avg:0.044) Loss 32.791759 (avg:50.375900)
# Epoch: [9/10][21000/23040] Time 0.054 (avg:0.044) Loss 86.680702 (avg:50.297120)
# Epoch: [9/10][22000/23040] Time 0.041 (avg:0.044) Loss 35.548115 (avg:50.276051)
# Epoch: [9/10][23000/23040] Time 0.017 (avg:0.044) Loss 1.569188 (avg:50.242221)
# Epoch: [10/10][0/23040] Time 0.032 (avg:0.032) Loss 3.157963 (avg:3.157963)
# Epoch: [10/10][1000/23040] Time 0.060 (avg:0.044) Loss 24.131353 (avg:50.750244)
# Epoch: [10/10][2000/23040] Time 0.030 (avg:0.045) Loss 36.260204 (avg:50.800412)
# Epoch: [10/10][3000/23040] Time 0.029 (avg:0.044) Loss 36.576645 (avg:50.598310)
# Epoch: [10/10][4000/23040] Time 0.090 (avg:0.044) Loss 72.846863 (avg:50.079379)
# Epoch: [10/10][5000/23040] Time 0.053 (avg:0.044) Loss 37.597580 (avg:49.772557)
# Epoch: [10/10][6000/23040] Time 0.060 (avg:0.044) Loss 42.054466 (avg:50.507164)
# Epoch: [10/10][7000/23040] Time 0.047 (avg:0.044) Loss 47.545918 (avg:50.300402)
# Epoch: [10/10][8000/23040] Time 0.091 (avg:0.044) Loss 47.228649 (avg:50.369656)
# Epoch: [10/10][9000/23040] Time 0.053 (avg:0.044) Loss 26.086943 (avg:50.170907)
# Epoch: [10/10][10000/23040] Time 0.090 (avg:0.044) Loss 182.174850 (avg:50.245838)
# Epoch: [10/10][11000/23040] Time 0.053 (avg:0.044) Loss 65.941147 (avg:49.939681)
# Epoch: [10/10][12000/23040] Time 0.031 (avg:0.044) Loss 49.701878 (avg:50.109274)
# Epoch: [10/10][13000/23040] Time 0.017 (avg:0.044) Loss 4.683045 (avg:50.523251)
# Epoch: [10/10][14000/23040] Time 0.053 (avg:0.044) Loss 72.612396 (avg:50.301632)
# Epoch: [10/10][15000/23040] Time 0.018 (avg:0.044) Loss 0.000000 (avg:50.381050)
# Epoch: [10/10][16000/23040] Time 0.048 (avg:0.044) Loss 188.968277 (avg:50.320684)
# Epoch: [10/10][17000/23040] Time 0.063 (avg:0.044) Loss 21.579134 (avg:50.559157)
# Epoch: [10/10][18000/23040] Time 0.041 (avg:0.044) Loss 23.896452 (avg:50.429877)
# Epoch: [10/10][19000/23040] Time 0.063 (avg:0.044) Loss 55.187557 (avg:50.284716)
# Epoch: [10/10][20000/23040] Time 0.039 (avg:0.044) Loss 73.778397 (avg:50.227287)
# Epoch: [10/10][21000/23040] Time 0.030 (avg:0.044) Loss 115.690094 (avg:50.301107)
# Epoch: [10/10][22000/23040] Time 0.017 (avg:0.044) Loss 1.823779 (avg:50.321568)
# Epoch: [10/10][23000/23040] Time 0.038 (avg:0.044) Loss 59.282711 (avg:50.240804)
# 0/200 eval /home/ygao26/Desktop/final/tmpRCF/RCF/epoch-10-testing-record-black/250047.png...
# 0/200 eval /home/ygao26/Desktop/final/tmpRCF/RCF/epoch-10-testing-record-black/250047.png...
# 0/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/250047.png...
# 1/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/77062.png...
# 2/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/16068.png...
# 3/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/107014.png...
# 4/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/51084.png...
# 5/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/238025.png...
# 6/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/198087.png...
# 7/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/189013.png...
# 8/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/230063.png...
# 9/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/279005.png...
# 10/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/226060.png...
# 11/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/246009.png...
# 12/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/220003.png...
# 13/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/230098.png...
# 14/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/43051.png...
# 15/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/188025.png...
# 16/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/285022.png...
# 17/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/159002.png...
# 18/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/80085.png...
# 19/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/189029.png...
# 20/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/71076.png...
# 21/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/106047.png...
# 22/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/181021.png...
# 23/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/267036.png...
# 24/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/196027.png...
# 25/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/208078.png...
# 26/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/335088.png...
# 27/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/207049.png...
# 28/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/107045.png...
# 29/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/268074.png...
# 30/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/334025.png...
# 31/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/41085.png...
# 32/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/128035.png...
# 33/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/226033.png...
# 34/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/81066.png...
# 35/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/161045.png...
# 36/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/130066.png...
# 37/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/160006.png...
# 38/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/384022.png...
# 39/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/97010.png...
# 40/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/141048.png...
# 41/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/28083.png...
# 42/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/326085.png...
# 43/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/147077.png...
# 44/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/385022.png...
# 45/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/235098.png...
# 46/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/48025.png...
# 47/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/112056.png...
# 48/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/179084.png...
# 49/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/232076.png...
# 50/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/101084.png...
# 51/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/326025.png...
# 52/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/289011.png...
# 53/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/49024.png...
# 54/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/103078.png...
# 55/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/29030.png...
# 56/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/306052.png...
# 57/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/250087.png...
# 58/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/268048.png...
# 59/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/130014.png...
# 60/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/147080.png...
# 61/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/118072.png...
# 62/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/226043.png...
# 63/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/104055.png...
# 64/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/35049.png...
# 65/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/281017.png...
# 66/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/70090.png...
# 67/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/189096.png...
# 68/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/306051.png...
# 69/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/196062.png...
# 70/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/120003.png...
# 71/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/118031.png...
# 72/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/335094.png...
# 73/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/45000.png...
# 74/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/105027.png...
# 75/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/368037.png...
# 76/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/288024.png...
# 77/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/376086.png...
# 78/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/87015.png...
# 79/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/43033.png...
# 80/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/187099.png...
# 81/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/247003.png...
# 82/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/61034.png...
# 83/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/207038.png...
# 84/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/134049.png...
# 85/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/17067.png...
# 86/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/217090.png...
# 87/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/16004.png...
# 88/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/141012.png...
# 89/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/3063.png...
# 90/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/145059.png...
# 91/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/243095.png...
# 92/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/388018.png...
# 93/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/100007.png...
# 94/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/120093.png...
# 95/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/70011.png...
# 96/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/296028.png...
# 97/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/257098.png...
# 98/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/206097.png...
# 99/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/79073.png...
# 100/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/94095.png...
# 101/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/217013.png...
# 102/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/176051.png...
# 103/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/372019.png...
# 104/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/108036.png...
# 105/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/223060.png...
# 106/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/259060.png...
# 107/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/209021.png...
# 108/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/100039.png...
# 109/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/69007.png...
# 110/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/81095.png...
# 111/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/309040.png...
# 112/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/102062.png...
# 113/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/35028.png...
# 114/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/393035.png...
# 115/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/69000.png...
# 116/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/14085.png...
# 117/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/6046.png...
# 118/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/106005.png...
# 119/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/140088.png...
# 120/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/365072.png...
# 121/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/196088.png...
# 122/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/123057.png...
# 123/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/112090.png...
# 124/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/196040.png...
# 125/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/185092.png...
# 126/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/107072.png...
# 127/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/33044.png...
# 128/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/347031.png...
# 129/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/253092.png...
# 130/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/48017.png...
# 131/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/78098.png...
# 132/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/65084.png...
# 133/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/80090.png...
# 134/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/104010.png...
# 135/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/228076.png...
# 136/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/388067.png...
# 137/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/302022.png...
# 138/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/253016.png...
# 139/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/145079.png...
# 140/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/41006.png...
# 141/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/15062.png...
# 142/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/247012.png...
# 143/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/20069.png...
# 144/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/23050.png...
# 145/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/183066.png...
# 146/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/15011.png...
# 147/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/296058.png...
# 148/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/160067.png...
# 149/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/277053.png...
# 150/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/157087.png...
# 151/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/2018.png...
# 152/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/346016.png...
# 153/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/140006.png...
# 154/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/187058.png...
# 155/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/189006.png...
# 156/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/100099.png...
# 157/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/103029.png...
# 158/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/64061.png...
# 159/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/225022.png...
# 160/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/201080.png...
# 161/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/175083.png...
# 162/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/164046.png...
# 163/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/258089.png...
# 164/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/108004.png...
# 165/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/36046.png...
# 166/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/101027.png...
# 167/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/290035.png...
# 168/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/108069.png...
# 169/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/103006.png...
# 170/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/69022.png...
# 171/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/41029.png...
# 172/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/14092.png...
# 173/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/109055.png...
# 174/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/226022.png...
# 175/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/10081.png...
# 176/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/202000.png...
# 177/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/5096.png...
# 178/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/157032.png...
# 179/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/384089.png...
# 180/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/118015.png...
# 181/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/134067.png...
# 182/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/146074.png...
# 183/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/41096.png...
# 184/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/168084.png...
# 185/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/71099.png...
# 186/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/159022.png...
# 187/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/388006.png...
# 188/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/156054.png...
# 189/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/8068.png...
# 190/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/81090.png...
# 191/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/249021.png...
# 192/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/223004.png...
# 193/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/92014.png...
# 194/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/317043.png...
# 195/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/206062.png...
# 196/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/117025.png...
# 197/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/163096.png...
# 198/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/163004.png...
# 199/200 eval /home/ygao26/Desktop/final/tmpleakyrelu+lr+lbd+19/eRCF/epoch-10-testing-record-black/344010.png...

# %% [markdown]
# ## 8. Detect overfitting/underfitting problem

# %%
# Plot train and validation loss

# mpl.rcParams['text.color'] = 'black'
# mpl.rcParams['axes.titlecolor'] = 'w'
# mpl.rcParams['xtick.color'] = 'w'
# mpl.rcParams['ytick.color'] = 'w'
# mpl.rcParams['axes.labelcolor'] = 'w'

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(train_loss, label='Training Loss')
ax.plot(val_loss, label='Validation Loss')
ax.set_title('Loss vs. Epochs', fontsize=16)
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
ax.legend(fontsize=14)
ax.grid(True)
plt.show()

# %% [markdown]
# At the beginning we see the model is underfitting, but we do not see that after epoch 6~7. Overall we conclude the model fits well and no regularization such as dropout, batch normalization, or early stop is needed.

# %% [markdown]
# ## 9. Measure model performance

# %% [markdown]
# In edge detection world, there are two industry standard metrics to measure model performance. The first one is referred as optimal dataset scale (ODS) which employs a fixed threshold for all images in a dataset. The second is called optimal image scale (OIS) which selects an optimal threshold for each image. For the two metrics, the higher the better.

# %%
# Linux only execution
# if you run Windows, it will report an error so comment it out
from edges_eval_dir import edges_eval_dir
edges_eval_dir(test_pre, test_gt)

# %% [markdown]
# Copy eval_bdry.txt to root_dir and rename it to eval_bdry_ercf.txt. We have eval_bdry_rcf.txt generated from notebook Edge Detection RCF final.ipynb so the prep work for performance evaluation is done. Run below code to aggregate the results together.

# %%
# Show ODS OIS scores for RCF and enhanced RCF models
perf_rcf = pd.read_csv("eval_bdry_rcf.txt", header=None, delimiter=' ')
perf_rcf = perf_rcf[[3, 6]]
perf_rcf.columns = ["ODS", "OIS"]
perf_rcf.index = ["RCF"]
perf_ercf = pd.read_csv("eval_bdry_ercf.txt", header=None, delimiter=' ')
perf_ercf = perf_ercf[[3, 6]]
perf_ercf.columns = ["ODS", "OIS"]
perf_ercf.index = ["enhanced RCF"]
perf_df = pd.concat([perf_rcf,perf_ercf], axis = 0)
perf_df
# Out:
#                    ODS       OIS
# RCF           0.757982  0.775395
# enhanced RCF  0.761043  0.776080

# %% [markdown]
# Both ODS and OIS scores improves in the enhanced RCF model, which proves our new model is more powerful in edge detection than the traditional RCF model.

# %% [markdown]
# ## 10. Model Results

# %% [markdown]
# ### 10a. Compare predicted sketched against ground truth

# %% [markdown]
# First, we need to convert .mat ground truth file to .png.

# %%
gt_img_dir = join(Root_dir, 'data/HED-BSDS/gt_img/')
if not isdir(gt_img_dir):
    os.makedirs(gt_img_dir)
    
for filename in os.listdir(test_gt):
    data = sio.loadmat(join(test_gt,filename))
    edge_data = data['groundTruth'][0][0][0][0][1]
    #Store the normalized data: 0<x<1
    #So need to restore back to 0<x<255
    edge_data_255 = Image.fromarray((edge_data * 255).astype(np.uint8))
    new_img_name = filename.split('.')[0]+'.png'
    edge_data_255.save(join(gt_img_dir, new_img_name))

# %%
imgp1 = '334025.png'
imgj1 = '334025.jpg'

image1_list = [join(Root_dir, 'data/HED-BSDS/test/', imgj1), join(Root_dir, 'data/HED-BSDS/gt_img/', imgp1),
join(Root_dir, 'tmpRCF/RCF/epoch-10-testing-record-black/', imgp1),
join(Root_dir, 'tmpERCF/eRCF/epoch-10-testing-record-black/', imgp1)]

fig = plt.figure(figsize=(12, 12))

for idx, img in enumerate(image1_list):
    img = cv2.imread(img, 3)
    b,g,r = cv2.split(img)    
    img = cv2.merge([r,g,b])
    fig.add_subplot(1, 4, idx + 1)
    title = 'Actual' if idx == 0 else 'Ground Truth' if idx == 1 else 'RCF' if idx == 2 else 'Enhanced RCF'
    plt.title(title)
    plt.imshow(img)
 # labels along the bottom edge are off
plt.show()

# %%
imgp2 = '388006.png'
imgj2 = '388006.jpg'

image2_list = [join(Root_dir, 'data/HED-BSDS/test/', imgj2), join(Root_dir, 'data/HED-BSDS/gt_img/', imgp2),
join(Root_dir, 'tmpRCF/RCF/epoch-10-testing-record-black/', imgp2),
join(Root_dir, 'tmpERCF/eRCF/epoch-10-testing-record-black/', imgp2)]

fig = plt.figure(figsize=(12, 12))

for idx, img in enumerate(image2_list):
    img = cv2.imread(img, 3)
    b,g,r = cv2.split(img)    
    img = cv2.merge([r,g,b])
    fig.add_subplot(1, 4, idx + 1)
    title = 'Actual' if idx == 0 else 'Ground Truth' if idx == 1 else 'RCF' if idx == 2 else 'Enhanced RCF'
    plt.title(title)
    plt.imshow(img)
plt.show()

# %% [markdown]
# As we can tell from the two comparisons above, for the temple image, our predicted sketch looks similar to RCF model but has more details in the floor. For the portrait, our model shows less noise on the upper right corner, which is good because we want more emphasis on the portrait and less information outside that.

# %% [markdown]
# ### 10b. Compare graduate change on the sketch

# %%
grad1 = join(Root_dir, 'tmpERCF/eRCF/epoch-10-testing-record-graduate/', imgp1)

fig = plt.figure(figsize=(12, 12))

img = cv2.imread(grad1, 3)
b,g,r = cv2.split(img)    
img = cv2.merge([r,g,b])
plt.title("Graduate change from stage 1 to final output")
plt.imshow(img)

# %%
grad2 = join(Root_dir, 'tmpERCF/eRCF/epoch-10-testing-record-graduate/', imgp2)

fig = plt.figure(figsize=(12, 12))

img = cv2.imread(grad2, 3)
b,g,r = cv2.split(img)    
img = cv2.merge([r,g,b])
plt.title("Graduate change from stage 1 to final output")
plt.imshow(img)

# %% [markdown]
# ### 10c. Try the model on my own pictures

# %% [markdown]
# Load the pictures I took on my phone to Root_dir/data/Yifan/test. Create a test.lst under that.

# %%
yifan_dir = join(Root_dir, 'data/YIFAN/test/')
if not isdir(yifan_dir):
    os.makedirs(yifan_dir)

yifan_rt_dir = join(Root_dir, 'data/YIFAN/result/')
if not isdir(yifan_rt_dir):
    os.makedirs(yifan_rt_dir)

yifan_dataset = BSDS_Dataloader(root='data/YIFAN',  split= "test")
yifan_loader = DataLoader(yifan_dataset, shuffle=False)
    
model = ERCF()
model.cuda()
model.load_state_dict(torch.load(join(tmp_dir, 'checkpoint_epoch10.pth'))['state_dict'])
model.eval()

scale = [0.5, 1, 1.5]

for idx, image in enumerate(yifan_loader):
    filename = os.listdir(yifan_dir)[idx]
    image = image[0]
    image_in = image.numpy().transpose((1,2,0))
    _, H, W = image.shape
    multi_fuse = np.zeros((H, W), np.float32)
    for k in range(0, len(scale)):
        im_ = cv2.resize(image_in, None, fx=scale[k], fy=scale[k], interpolation=cv2.INTER_LINEAR)
        im_ = im_.transpose((2,0,1))
        results = model(torch.unsqueeze(torch.from_numpy(im_).cuda(), 0))
        result = torch.squeeze(results[-1].detach()).cpu().numpy()
        fuse = cv2.resize(result, (W, H), interpolation=cv2.INTER_LINEAR)
        multi_fuse += fuse
    multi_fuse = multi_fuse / len(scale)
    # Black background
    result_out = Image.fromarray((multi_fuse * 255).astype(np.uint8))
    result_out.save(join(yifan_rt_dir, "%s.png" % filename))

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

yifan_images_short = os.listdir(yifan_dir)
yifan_images = list(map(lambda x: yifan_dir + x, yifan_images_short))
yifan_labels_short = os.listdir(yifan_rt_dir)
yifan_labels = list(map(lambda x: yifan_rt_dir + x, yifan_labels_short))
fig = plt.figure(figsize=(16, 16))

for idx, img in enumerate(zip(yifan_images, yifan_labels)):
    img1 = cv2.imread(img[0], 3)
    b,g,r = cv2.split(img1)    
    img1 = cv2.merge([r,g,b])
    img2 = cv2.imread(img[1], 3)
    b,g,r = cv2.split(img2)    
    img2 = cv2.merge([r,g,b])
    fig.add_subplot(2, 2, idx * 2 + 1)
    plt.imshow(img1)
    fig.add_subplot(2, 2, idx * 2 + 2)
    plt.imshow(img2)
plt.show()
